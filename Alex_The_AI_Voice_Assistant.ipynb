# %% [markdown]
# # <span style="color:purple">Alex the smart AI-Assistant:</span>

# %% [markdown]
# ### To install any of the libraries or applications use <br> anaconda prompt: conda install name <br> or <br> !pip install name

# %%
#import libraries:

import speech_recognition as sr
import pyttsx3
import pywhatkit
import datetime
import wikipedia
import pyjokes
import webbrowser
import pyNASA
import speedtest
import pyspeedtest
import COVID19Py
import pandas as pd
import requests, pytemperature, json
import covid19_data
from covid19_data import JHU
import quotes
from PIL import Image 
from requests import get
from json import loads
import os

# %%
#setup the voice to text:

listener = sr.Recognizer()
engine = pyttsx3.init()
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id) # 0 for male voice, 1 for female voice
print(voices[1].id)
engine.setProperty('rate', 165) #change the rate of speech from 165 to any value

#define the talk function for speech output:

def talk(text):
    engine.say(text)
    engine.runAndWait()
                   
def take_command():
    try:
        with sr.Microphone() as source:
            print('ALex activated....')
            voice = listener.listen(source)
            command = listener.recognize_google(voice)
            command = command.lower()
            if 'alex' in command:
                command = command.replace('alex', '')
                print(command)               
    except:
        pass
    return(command)

#define run_alex function, play for youtube:
def run_alex():
    command = take_command()
    print(command)
    if 'play' in command:
        song = command.replace('play', '')
        talk('playing ' + song)
        pywhatkit.playonyt(song)

    #date and time:       
   
    elif 'time' in command:                                     
        time = datetime.datetime.now().strftime('%H:%M %p')
        print(time)
        talk ('current time is' + time)                     
    elif 'date' in command:
        date = datetime.datetime.now().strftime("%A:%B the %d")
        print(date)
        talk('todays date is' + date)

    #open browser features:
    #For Facebook put your ID without curley braces:
    #use the same format to add any link
    
    elif 'gmail' in command:                                  
        webbrowser.open('http://mail.google.com/mail/u/0/#inbox') 
        talk('gmail is here')
    elif 'whatsapp' in command:
        webbrowser.open('https://web.whatsapp.com/')
        talk('heres your whatsapp')
    elif 'google' in command:
        webbrowser.open('https://www.google.com/') 
        talk('google is here')
    elif 'facebook' in command:
        webbrowser.open('https://www.facebook.com/{FBID}) 
        talk('here you go mate')
    elif 'netflix' in command:
        webbrowser.open('https://www.netflix.com/browse') 
        talk('netflix is right here!')
    elif 'youtube' in command:
        webbrowser.open('https://www.youtube.com/')
        talk('here you go mate')  

    #wikipedia searches: how do..?, what is..?,who the heck..?, who is? 

    elif 'how do' in command:                         
        person = command.replace('how do', '')
        info = wikipedia.summary(person, 1)
        print(info)
        talk(info)
    elif 'what is' in command:
        person = command.replace('what is', '')
        info = wikipedia.summary(person, 1)
        print(info)
        talk(info)
    elif 'who the heck is' in command:
        person = command.replace('who the heck is', '')
        info = wikipedia.summary(person, 1)
        print(info)
        talk(info)  
    elif 'who is' in command:
        person = command.replace('who the heck is', '')
        info = wikipedia.summary(person, 1)
        print(info)
        talk(info)                                                                  
    #general conversation:  
    elif'your name' in command:
        talk('hi i am alex')
    elif'how is' in command:                                       
        talk('thats a very comlicated thing to answer')
    elif'where are you' in command:
        talk('i wish i could tell you that')
    elif'what are you doing' in command:
        talk('thinking if i can think')
    elif'how are you' in command:
        talk('enjoying life, what about you?')
    elif 'date' in command:
        talk('sorry, I have a headache')
    elif 'who are you' in command:
        talk("i am a virtual assistant")
    elif 'who built you' in command:
        talk("i was built using python script by my creator")
    elif 'who build you' in command:
        talk("i was built using python script by my creator")
    elif 'who made you' in command:
        talk("i am a virtual assistant")
    elif 'who created you' in command:
        talk("i am created by my creator, who took me as a weekend project but gradually fell in love with me")    
    elif 'are you single' in command:
        talk('I am in a relationship with wifi')
    elif 'joke' in command:
        talk(pyjokes.get_joke())
    elif 'what do you think' in command:
        talk('i can only think binary')
    elif 'love' in command:
        talk("only thing i can advise you bud love is a stupid thing")
    elif 'what is your name' in command:
        talk('talk you can call me anything you like')
        
    #wishing functions:
      
    
    elif'greetings' in command:
        talk('greeings mate')
    elif 'good night' in command:                          
        talk('goodnight dear, catch the sweetest dream')
    elif 'good morning' in command:
        talk('goodmorning, hope you are having a good day, what can i do for you?')
    elif 'afternoon' in command:
        talk('goodafternoon mate')
    elif 'thank you' in command:
        talk('its my pleasure, sir') 
   
    #link to NASA
    #Create your own api key from the link: https://api.nasa.gov/
    #put the api key in place of {apikey} without curley braces                   

    elif 'nasa' in command: 
        webbrowser.open('https://api.nasa.gov/planetary/apod?api_key={apikey}') 
        talk('here is the nasa directed link for you')
    
    # monitoring internet speed:
    
    elif 'download speed' in command:                             
        st = pyspeedtest.SpeedTest('www.google.com')
        a = st.ping()
        print(round(a, 1) , "mb")
        talk("your current download speed at which you can download data is about"+ str(round(a, 1)) + "mb per second")
    elif 'net speed' in command:                             #internet speed  
        st = pyspeedtest.SpeedTest('www.google.com')
        a = st.ping()
        print(round(a, 1) , "mb")
        talk("your current internet speed is about"+ str(round(a, 1)) + "mb per second")
    elif 'internet speed' in command:                              
        st = pyspeedtest.SpeedTest('www.google.com')
        a = st.ping()
        print(round(a, 1) , "mb")
        talk("your current internet speed is about"+ str(round(a, 1)) + "mb per second")
    elif 'browsing speed' in command:                              
        st = pyspeedtest.SpeedTest('www.google.com')
        a = st.ping()
        print(round(a, 1) , "mb")
        talk("your current internet speed at which you are browsing is about"+ str(round(a, 1)) + "mb per second")  
        
    #weather forecating:
    #chage the following:
    #q=edit the place name
    #generate your api key from the link:http://api.openweathermap.org
    #replace the {apikey} with you key values without curley braces

   
        
    elif 'weather today' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}&units=metric')
        dict = r.json()
        results = dict['main']  
        print(results)
        talk("in degree celsius temperature as" + str(results))
    elif 'weather forecast' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}&units=metric')
        dict = r.json()
        results = dict['main']  
        print(results)
        talk("in degree celsius temperature as" + str(results))
    elif 'weather details' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}&units=metric')
        dict = r.json()
        results = dict['main']  
        print(results)
        talk("in degree celsius temperature as" + str(results))
    elif 'weather info' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}&units=metric')
        dict = r.json()
        results = dict['main']  
        print(results)
        talk("in degree celsius temperature as" + str(results))
    elif 'wind speed' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}')
        dict = r.json()
        results = dict['wind']
        print(results)
        talk("wind" + str(results) + "degree")    
    elif 'wind today' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}')
        dict = r.json()
        results = dict['wind']
        print(results)
        talk("wind" + str(results) + "degree")
    elif 'how windy' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}')
        dict = r.json()
        results = dict['wind']
        print(results)
        talk("wind" + str(results) + "degree")
    elif 'wind velocity' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}')
        dict = r.json()
        results = dict['wind']
        print(results)
        talk("wind" + str(results) + "degree")
    elif 'rain status' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}')
        dict = r.json()
        results = dict['weather']
        print(results)
        talk(results)
    elif 'rain forecast' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}')
        dict = r.json()
        results = dict['weather']
        print(results)
        talk(results)
    elif 'precipitation' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}')
        dict = r.json()
        results = dict['weather']
        print(results)
        talk(results)
    elif 'co-ordinates' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}')
        dict = r.json()
        results = dict['coord']
        print(results)
        talk("co-ordinates are" + str(results))
    elif 'coordinates' in command:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Kota&appid={apikey}')
        dict = r.json()
        results = dict['coord']
        print(results)
        talk("co-ordinates are" + str(results))
        
    elif 'coronavirus cases in us' in command:      
        total = covid19_data.jsonByName("US")
        print(total)
        talk("coronacirus cases in US:" + str(total))
    elif 'covid cases in us' in command:                           
        total = covid19_data.jsonByName("US")
        print(total)
        talk("coronavirus cases in US:" + str(total))    
    
    elif 'coronavirus cases in china' in command:
        total = covid19_data.jsonByName("china")
        print(total)
        talk("in china the number of :" + str(total))
    elif 'covid cases in china' in command:
        total = covid19_data.jsonByName("china")
        print(total)
        talk("in china the number of :" + str(total))
    elif 'coronavirus cases in india' in command:
        total = covid19_data.jsonByName("india")
        print(total)
        talk("in india the number of :" + str(total))
    elif 'covid cases in india' in command:       
        total = covid19_data.jsonByName("india")
        print(total)
        talk("in india the number of :" + str(total))
    elif 'global covid cases' in command:       
        total = covid19_data.jsonByName("Total")
        print(total)
        talk("global covid cases includes :" + str(total))
    elif 'covid cases worldwide' in command:      
        total = covid19_data.jsonByName("Total")
        print(total)
        talk("global covid cases includes :" + str(total))
    elif 'total covid cases' in command:      
        total = covid19_data.jsonByName("Total")
        print(total)
        talk("total covid cases throughout the world includes :" + str(total))
   
    elif'covid summary' in command:
        total1 = covid19_data.jsonByName("china")
              
        total2 = covid19_data.jsonByName("india")
        
        total3 = covid19_data.jsonByName("US")
       
        total4 = covid19_data.jsonByName("Total")
        full = ("CHINA:" + str(total1), "INDIA:" + str(total2), "US:" + str(total3), "Global:" + str(total4))
        results = print(full)
        talk(full) 
    #give the image location of the picture you wish to show:
    elif'how you look' in command:
        im = Image.open(r"C:\Users\.....image location") 
        im.show()
        talk('i am sending you my picture, checkout and tell me')
    
    #get inspiring quotes whenever you say say something
    elif 'say'in command:        
        r = requests.get('http://api.forismatic.com//api//1.0//?method=getQuote&format=json&lang=en')
        dict = r.json()
        results = dict['quoteText']  
        print(results)
        talk("always remember" + str(results))
    #get top 10 news heads from 
    elif 'news today'in command:
        URL = "https://newsapi.org/v1/articles?source=bbc-news&sortBy=top&apiKey=4dbc17e007ab436fb66416009dfb59a8"
        open_bbc_page = requests.get(URL).json()
        article = open_bbc_page["articles"] 
        results = [] 
        for ar in article: 
            results.append(ar["title"]) 
        for i in range(len(results)): 
            print(i + 1, results[i])
        from win32com.client import Dispatch 
        engine.setProperty('rate', 200)
        talk("here the top 10 news for today :" + str(results))
        if __name__ == '__main__': 
            NewsFromBBC()                      
    else:
        talk('didnt gotcha, can you please say again')
        
run_alex()
# Out:
# HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0
# ALex activated....
# news today
# 1 Trump urges Congress to amend 'wasteful' coronavirus aid bill
# 2 Trump pardons two convicted by Mueller inquiry
# 3 Dr Deborah Birx: White House virus expert quits over holiday travel
# 4 Biden: 'Darkest days' ahead in fight against Covid
# 5 US sues Walmart for alleged role in opioid crisis
# 6 Messi breaks Pele scoring record
# 7 Stranded at sea: Survivors' stories
# 8 Covid-19: French agree to ease virus travel ban
# 9 Israel election: New poll due after unity government crumbles
# 10 Alex Padilla to replace Kamala Harris in US Senate
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0fe8b018ce64> in <module>
#     322         talk('didnt gotcha, can you please say again')
#     323
# --> 324 run_alex()
#     325
#     326
#
# ...
